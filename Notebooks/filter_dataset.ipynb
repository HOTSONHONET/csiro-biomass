# %%
# %cd /home/hotson/kaggle_work/csiro-biomass/
# Out:
# /home/hotson/kaggle_work/csiro-biomass

# %%
import pandas as pd

# %%
train_df = pd.read_csv("/home/hotson/kaggle_work/csiro-biomass/dataset/train_df.csv")
train_df
# Out:
#         sample_id              image_path Sampling_Date State  \
# 0    ID1011485656  train/ID1011485656.jpg      2015/9/4   Tas
# 1    ID1012260530  train/ID1012260530.jpg      2015/4/1   NSW
# 2    ID1025234388  train/ID1025234388.jpg      2015/9/1    WA
# 3    ID1028611175  train/ID1028611175.jpg     2015/5/18   Tas
# 4    ID1035947949  train/ID1035947949.jpg     2015/9/11   Tas
# ..            ...                     ...           ...   ...
# 352   ID975115267   train/ID975115267.jpg      2015/7/8    WA
# 353   ID978026131   train/ID978026131.jpg      2015/9/4   Tas
# 354   ID980538882   train/ID980538882.jpg     2015/2/24   NSW
# 355   ID980878870   train/ID980878870.jpg      2015/7/8    WA
# 356   ID983582017   train/ID983582017.jpg      2015/9/1    WA
#
#                Species  Pre_GSHH_NDVI  Height_Ave_cm  Dry_Clover_g  \
# 0      Ryegrass_Clover           0.62         4.6667        0.0000
# 1              Lucerne           0.55        16.0000        0.0000
# ...

# %%
train_df[train_df['sample_id'] == "ID587125778"].to_dict()
# Out:
# {'sample_id': {274: 'ID587125778'},
#  'image_path': {274: 'train/ID587125778.jpg'},
#  'Sampling_Date': {274: '2015/6/29'},
#  'State': {274: 'Tas'},
#  'Species': {274: 'WhiteClover'},
#  'Pre_GSHH_NDVI': {274: 0.54},
#  'Height_Ave_cm': {274: 2.0},
#  'Dry_Clover_g': {274: 4.0911},
#  'Dry_Dead_g': {274: 25.3648},
#  'Dry_Green_g': {274: 1.6364},
#  'Dry_Total_g': {274: 31.0923},
#  'GDM_g': {274: 5.7275},
#  'State_code': {274: 1},
#  'Species_code': {274: 14}}
